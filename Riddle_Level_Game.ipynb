# %% [markdown]
# <a href="https://colab.research.google.com/github/enzobigi/Free-Time-Colab-Projects/blob/main/Riddle_Level_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

player ={
    "name" : "Adventureboy",
    "health" : 100,
    "weaponscore" : 1,
    "location" :  "Area 1"
}

area = 0


def showstatus():
  print ("\n === PLAYERSTATUS ===")
  print (f"Name: {player['name']}")
  print (f"Health: {player['health']}")
  print (f"Weapon Level: {player['weaponscore']}")

def intro():
  print ("This is a Riddle Survivor game. It will consist of riddles where you ahve to solve riddles in order to get out of the forest.")
  print ("\n You are a traveler alone in the forest, and you have 10 days to survive before the army comes to save you.")
  print ("You will need to avoid predators, kill animals for food, build survival materials using things you find, and stay safe in shelter.")

def riddle1():

  global area

  option1 = "a map"
  option2 = "a globe"
  option3 = "a mirage"
  answer = option1

  while True:
    question = input(f"\n\nI have cities, but no houses. I have mountains, but no trees. I have water, but no fish. What am I?: {option1}, {option2}, {option3}. \n")
    if question.lower() == answer:
      area += 1
      print ("Correct")
      player ['location'] = f"Area {area}"
      print (f"You are moving on to {player['location']}")
      break
    elif question == option1 or question == option2 or question == option3:
      print ("Wrong answer. You fail.")
      sys.exit()
    else:
      print ("That is not a valid option")


def riddle2():

  global area

  option1 = "a piano"
  option2 = "a computer"
  option3 = "a keyboard"
  answer = option3

  while True:

    question = input(f"\n\nI have roads, but no cars. I have keys, but no locks. I have space, but no room. What am I?: {option1}, {option2}, {option3}. \n")
    if question.lower() == answer:
      area += 1
      print ("Correct")
      player ['location'] = f"Area {area}"
      print (f"You are moving on to {player['location']}")
      break
    elif question == option1 or question == option2 or question == option3:
      print ("Wrong answer. You fail.")
      sys.exit()
    else:
      print ("That is not a valid option")



intro()
showstatus()
riddle1()
riddle2()
# Out:
# This is a Riddle Survivor game. It will consist of riddles where you ahve to solve riddles in order to get out of the forest.
#
#  You are a traveler alone in the forest, and you have 10 days to survive before the army comes to save you.
# You will need to avoid predators, kill animals for food, build survival materials using things you find, and stay safe in shelter.
#
#  === PLAYERSTATUS ===
# Name: Adventureboy
# Health: 100
# Weapon Level: 1
#
#
# I have cities, but no houses. I have mountains, but no trees. I have water, but no fish. What am I?: a map, a globe, a mirage.
# a map
# Correct
# You are moving on to Area 1
#
#
# I have roads, but no cars. I have keys, but no locks. I have space, but no room. What am I?: a piano, a computer, a keyboard.
# a piano
# Wrong answer. You fail.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# ...
