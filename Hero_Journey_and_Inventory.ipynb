# %% [markdown]
# <a href="https://colab.research.google.com/github/enzobigi/Free-Time-Colab-Projects/blob/main/Hero_Journey_and_Inventory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
player ={
    "name" : "Adventureboy",
    "health" : 100,
    "weaponscore" : 1
    "location" :  "Crowded tree area"
}

inventory = ["Block of Wood"]

def showstatus():
  print ("\n === PLAYERSTATUS ===")
  print (f"Name: {player['name']}")
  print (f"Health: {player['health']}")
  print (f"Weapon Level: {player['weaponscore']}")

def intro():
  print ("This is a Riddle Survivor game. It will consist of riddles but also common survival skills for you to survive.")
  print ("\n You are a traveler alone in the forest, and you have 10 days to survive before the army comes to save you.")
  print ("You will need to avoid predators, kill animals for food, build survival materials using things you find, and stay safe in shelter.")

def pickupitem():
  options = input(f"What item would you like to pick up: {option1}, {option2}, {option3}")



if player['location'] == "Crowded tree area":
    option1 = "Soft Sand"
    option2 = "Sharp Rocks"
    option3 = "Leaves"


showstatus()
# Out:
#  === PLAYERSTATUS ===
# Name: Adventureboy
# Health: 100
# Weapon Level: 1
