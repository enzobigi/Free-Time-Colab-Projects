# %% [markdown]
# <a href="https://colab.research.google.com/github/enzobigi/Free-Time-Colab-Projects/blob/main/Survival_rank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
food = int(input("How much food do you have (0-5):"))
water = int(input("How much water do you have (0-10):"))
fitness = int(input("How fit are you (0-10):"))
weapon = input("Do you have a weapon (yes or no):")

weaponscore = 0


if weapon.lower() == "yes":
  weaponscore += 15
else:
  "I was unable to complete the score because your answer for the weapon was incorrect."

totalpoints = food + water + fitness + weaponscore

officialscore = f"{totalpoints}/40"

print (f"your total score was: {officialscore}")

verdict = None

if totalpoints <= 5:
  print ("You are going to die immediately. Chance of survival: 5%")
elif 10 >= totalpoints > 6:
  print ("You have a very high chance of dying. Chance of survival: 15%")
elif 17 >= totalpoints > 10:
  print ("You need to get very lucky if you want to survive. Chance of survival: 25%")
elif 25 >= totalpoints > 17:
  print ("If you want to survive you better get to work. Chance of survival: 33%")
elif 32 >= totalpoints > 25:
  print ("You are weak but still may be ok. Chance of survival: 50%")
elif 36 >= totalpoints > 32:
  print ("You have a good foundation to survive. Chance of survival: 75%")
elif 40 >= totalpoints > 36:
  print ("You have all the necessary requirements to survive. Chance of survival: 90%")
# Out:
# How much food do you have (0-5):3
# How much water do you have (0-10):2
# How fit are you (0-10):8
# Do you have a weapon (yes or no):yes
# your total score was: 28/40
# You are weak but still may be ok. Chance of survival: 50%
